# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="auto"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Proyecto </p></tp>
#             <tp><p style="font-size:150%;text-align:center">Representación de reglas</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %% [markdown]
# ## Descripción del problema <a class="anchor" id="prob"></a>
#
# ([Volver al inicio](#inicio))
#
#
# Este es uno de los hexagramas mágicos que cumplen con las condiciones:
#
# <img src="./img/problema.png" width="400px"/>

# %% [markdown]
# ## Reglas <a class="anchor" id="forms"></a>
#
# Para hacer más concisa la primera regla, hacemos la siguiente definición de lo que son las lineas rectas en el hexagrama (tenga en cuenta que las lineas son un subconjunto de todas las casillas):
#
# $$l_1 = \{1,3,6,8\}$$
# $$l_2 = \{1,4,7,11\}$$
# $$l_3 = \{8,9,10,11\}$$
# $$l_4 = \{2,3,4,5\}$$
# $$l_5 = \{2,6,9,12\}$$
# $$l_6 = \{5,7,10,12\}$$
#
# Las restricciones y su representación usando lógica proposicional son las siguientes:
#
# 1. La suma de los números en cualquier línea recta es 26:
#
# $$\bigwedge_{l \in Lineas} \left(\bigvee_{n \in Numeros} NenC_{n,l_{[1]}}+NenC_{n,l_{[2]}}+NenC_{n,l_{[3]}}+NenC_{n,l_{[4]}} = NenC_{26,l_{[1]}+l_{[2]}+l_{[3]}+l_{[4]}}\right)$$
#
# 2. Todas las casillas deben estar ocupadas:
# $$\bigwedge_{c \in Casillas} \left(\bigvee_{n \in Numeros}NenC_{n,c}\right)$$
#
#
# 3. No pueden haber números repetidos:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{e \neq c} NenC_{n,e}\right)\right)$$
#
#
# 4. Solo debe haber un número por casilla:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{m \neq n} NenC_{m,c}\right)\right)$$

# %% [markdown]
# ## Implementación de las reglas
#
# En el archivo `Hexagramas_arr` hemos implementado las cuatro reglas. Puede correr el siguiente código para visualizar el resultado, y puede entrar al archivo para explorar la implementación:

# %%
from Hexagrama_arr import *
from Logica import *

# %%
n = Numero()

# %% [markdown]
# Observe que el objeto tiene un atributo `reglas`, en el cual está una lista con las tres reglas implementadas en Python:

# %%
n.reglas
# Out:
# ['(((((((((((((ĀYę)Y(ņYş))O(((ĀYę)Y(ŇYŞ))O((ĀYĢ)Y(ĽYş))))O(((ĀYĢ)Y(ŇYŕ))O(((ĀYģ)Y(ĽYŞ))O((ĀYģ)Y(ņYŕ)))))O((((āYĘ)Y(ņYş))O(((āYĘ)Y(ŇYŞ))O((āYĢ)Y(ļYş))))O(((āYĢ)Y(ŇYŔ))O(((āYģ)Y(ļYŞ))O((āYģ)Y(ņYŔ))))))O(((((ĊYĘ)Y(ĽYş))O(((ĊYĘ)Y(ŇYŕ))O((ĊYę)Y(ļYş))))O(((ĊYę)Y(ŇYŔ))O(((ĊYģ)Y(ļYŕ))O((ĊYģ)Y(ĽYŔ)))))O((((ċYĘ)Y(ĽYŞ))O(((ċYĘ)Y(ņYŕ))O((ċYę)Y(ļYŞ))))O(((ċYę)Y(ņYŔ))O(((ċYĢ)Y(ļYŕ))O((ċYĢ)Y(ĽYŔ)))))))O((((((ĀYĚ)Y(ŅYş))O(((ĀYĚ)Y(ŇYŝ))O((ĀYġ)Y(ľYş))))O(((ĀYġ)Y(ŇYŖ))O(((ĀYģ)Y(ľYŝ))O((ĀYģ)Y(ŅYŖ)))))O((((ĂYĘ)Y(ŅYş))O(((ĂYĘ)Y(ŇYŝ))O((ĂYġ)Y(ļYş))))O(((ĂYġ)Y(ŇYŔ))O(((ĂYģ)Y(ļYŝ))O((ĂYģ)Y(ŅYŔ))))))O(((((ĉYĘ)Y(ľYş))O(((ĉYĘ)Y(ŇYŖ))O((ĉYĚ)Y(ļYş))))O(((ĉYĚ)Y(ŇYŔ))O(((ĉYģ)Y(ļYŖ))O((ĉYģ)Y(ľYŔ)))))O((((ċYĘ)Y(ľYŝ))O(((ċYĘ)Y(ŅYŖ))O((ċYĚ)Y(ļYŝ))))O((((ċYĚ)Y(ŅYŔ))O((ċYġ)Y(ļYŖ)))O(((ċYġ)Y(ľYŔ))O((ĀYě)Y(ńYş))))))))O(((((((ĀYě)Y(ŇYŜ))O(((ĀYĠ)Y(ĿYş))O((ĀYĠ)Y(ŇYŗ))))O(((ĀYģ)Y(ĿYŜ))O(((ĀYģ)Y(ńYŗ))O((ăYĘ)Y(ńYş)))))O((((ăYĘ)Y(ŇYŜ))O(((ăYĠ)Y(ļYş))O((ăYĠ)Y(ŇYŔ))))O(((ăYģ)Y(ļYŜ))O(((ăYģ)Y(ńYŔ))O((ĈYĘ)Y(ĿYş))))))O(((((ĈYĘ)Y(ŇYŗ))
# ...

# %% [markdown]
# La clase `Numero` crea de una vez el descriptor, mediante el cual podemos decodificar las letras:

# %%
n.NenC.escribir('ñ')
# Out:
# 'El número 9  está en la casilla (-1)'

# %%
n.NenC.escribir('Ç')
# Out:
# 'El número 3  está en la casilla (-4)'

# %% [markdown]
# También podemos revisar regla por regla. Observe que las fórmulas incluyen un método `ver` para visualizar más fácilmente las reglas:

# %%
# %%time
A = inorder_to_tree(n.reglas[0])
print(A.ver(n.NenC))
# Out:
# (((((((((((El número 0  está en la casilla (0) >  no El número 1  está en la casilla (0)) Y ((El número 0  está en la casilla (0) >  no El número 2  está en la casilla (0)) Y (El número 0  está en la casilla (0) >  no El número 3  está en la casilla (0)))) Y ((El número 0  está en la casilla (0) >  no El número 4  está en la casilla (0)) Y ((El número 0  está en la casilla (0) >  no El número 5  está en la casilla (0)) Y (El número 0  está en la casilla (0) >  no El número 6  está en la casilla (0))))) Y (((El número 0  está en la casilla (0) >  no El número 7  está en la casilla (0)) Y ((El número 0  está en la casilla (0) >  no El número 8  está en la casilla (0)) Y (El número 0  está en la casilla (0) >  no El número 9  está en la casilla (0)))) Y ((El número 0  está en la casilla (0) >  no El número 10  está en la casilla (0)) Y ((El número 0  está en la casilla (0) >  no El número 11  está en la casilla (0)) Y (El número 1  está en la casilla (0) >  no El número 0  está en la ca
# ...

# %% [markdown]
# Ahora, procedemos a unir todas las reglas:

# %%
# %%time
A = inorder_to_tree(Ytoria_balanceada(n.reglas))
print(A.ver(n.NenC))
# Out:
# (((((((((((((((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 10  está en la casilla (5) Y El número 11  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 11  está en la casilla (5) Y El número 10  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 10  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 11  está en la casilla (7))))) O (((El número 0  está en la casilla (0) Y El número 10  está en la casilla (2)) Y (El número 11  está en la casilla (5) Y El número 1  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 11  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 10  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 11  está en la casilla (2)) Y (El número 10  está en la casilla (5) Y El número 1  está en la casilla (7)))))) O ((((El número 1  
# ...

# %% [markdown]
# ## Visualización
#
# El método `visualizar` permite representar visualmente el hexagrama mágico. \
# Ejemplo:

# %%
I = {}
for c in range(12):
    m = c  #Mismo numero en misma casilla
    literal = n.NenC.ravel([m, c])
    I[literal] = True

n.visualizar(I)

# %% [markdown]
# ---

# %% [markdown]
# ## Visualización de una solución

# %%
I = {}
literal1 = n.NenC.ravel([5,0])
I[literal1] = True
literal2 = n.NenC.ravel([4,1])
I[literal2] = True
literal3 = n.NenC.ravel([6,2])
I[literal3] = True
literal4 = n.NenC.ravel([10,3])
I[literal4] = True
literal5 = n.NenC.ravel([2,4])
I[literal5] = True
literal6 = n.NenC.ravel([8,5])
I[literal6] = True
literal7 = n.NenC.ravel([0,6])
I[literal7] = True
literal8 = n.NenC.ravel([3,7])
I[literal8] = True
literal9 = n.NenC.ravel([1,8])
I[literal9] = True
literal10 = n.NenC.ravel([11,9])
I[literal10] = True
literal11 = n.NenC.ravel([7,10])
I[literal11] = True
literal12 = n.NenC.ravel([9,11])
I[literal12] = True

n.visualizar(I)
