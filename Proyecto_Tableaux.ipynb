# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="auto"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Hexagrama mágico</p></tp>
#             <tp><p style="font-size:150%;text-align:center">Implementación de Tableaux</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %% [markdown]
# # Importar problema

# %%
from Logica import *
from Hexagrama_arr import *

# %% [markdown]
# ## Reglas <a class="anchor" id="forms"></a>
#
# Para hacer más concisa la primera regla, hacemos la siguiente definición de lo que son las lineas rectas en el hexagrama (tenga en cuenta que las lineas son un subconjunto de todas las casillas):
#
# $$l_1 = \{1,3,6,8\}$$
# $$l_2 = \{1,4,7,11\}$$
# $$l_3 = \{8,9,10,11\}$$
# $$l_4 = \{2,3,4,5\}$$
# $$l_5 = \{2,6,9,12\}$$
# $$l_6 = \{5,7,10,12\}$$
#
# Las restricciones y su representación usando lógica proposicional son las siguientes:
#
# 1. La suma de los números en cualquier línea recta es 26:
#
# $$\bigwedge_{l \in Lineas} \left(\bigvee_{n \in Numeros} NenC_{n,l_{[1]}}+NenC_{n,l_{[2]}}+NenC_{n,l_{[3]}}+NenC_{n,l_{[4]}} = NenC_{26,l_{[1]}+l_{[2]}+l_{[3]}+l_{[4]}}\right)$$
#
# 2. Todas las casillas deben estar ocupadas:
# $$\bigwedge_{c \in Casillas} \left(\bigvee_{n \in Numeros}NenC_{n,c}\right)$$
#
#
# 3. No pueden haber números repetidos:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{e \neq c} NenC_{n,e}\right)\right)$$
#
#
# 4. Solo debe haber un número por casilla:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{m \neq n} NenC_{m,c}\right)\right)$$

# %%
n = Numero()

# %%
n.reglas
# Out:
# ['(((((((((((((ĀYę)Y(ņYş))O(((ĀYę)Y(ŇYŞ))O((ĀYĢ)Y(ĽYş))))O(((ĀYĢ)Y(ŇYŕ))O(((ĀYģ)Y(ĽYŞ))O((ĀYģ)Y(ņYŕ)))))O((((āYĘ)Y(ņYş))O(((āYĘ)Y(ŇYŞ))O((āYĢ)Y(ļYş))))O(((āYĢ)Y(ŇYŔ))O(((āYģ)Y(ļYŞ))O((āYģ)Y(ņYŔ))))))O(((((ĊYĘ)Y(ĽYş))O(((ĊYĘ)Y(ŇYŕ))O((ĊYę)Y(ļYş))))O(((ĊYę)Y(ŇYŔ))O(((ĊYģ)Y(ļYŕ))O((ĊYģ)Y(ĽYŔ)))))O((((ċYĘ)Y(ĽYŞ))O(((ċYĘ)Y(ņYŕ))O((ċYę)Y(ļYŞ))))O(((ċYę)Y(ņYŔ))O(((ċYĢ)Y(ļYŕ))O((ċYĢ)Y(ĽYŔ)))))))O((((((ĀYĚ)Y(ŅYş))O(((ĀYĚ)Y(ŇYŝ))O((ĀYġ)Y(ľYş))))O(((ĀYġ)Y(ŇYŖ))O(((ĀYģ)Y(ľYŝ))O((ĀYģ)Y(ŅYŖ)))))O((((ĂYĘ)Y(ŅYş))O(((ĂYĘ)Y(ŇYŝ))O((ĂYġ)Y(ļYş))))O(((ĂYġ)Y(ŇYŔ))O(((ĂYģ)Y(ļYŝ))O((ĂYģ)Y(ŅYŔ))))))O(((((ĉYĘ)Y(ľYş))O(((ĉYĘ)Y(ŇYŖ))O((ĉYĚ)Y(ļYş))))O(((ĉYĚ)Y(ŇYŔ))O(((ĉYģ)Y(ļYŖ))O((ĉYģ)Y(ľYŔ)))))O((((ċYĘ)Y(ľYŝ))O(((ċYĘ)Y(ŅYŖ))O((ċYĚ)Y(ļYŝ))))O((((ċYĚ)Y(ŅYŔ))O((ċYġ)Y(ļYŖ)))O(((ċYġ)Y(ľYŔ))O((ĀYě)Y(ńYş))))))))O(((((((ĀYě)Y(ŇYŜ))O(((ĀYĠ)Y(ĿYş))O((ĀYĠ)Y(ŇYŗ))))O(((ĀYģ)Y(ĿYŜ))O(((ĀYģ)Y(ńYŗ))O((ăYĘ)Y(ńYş)))))O((((ăYĘ)Y(ŇYŜ))O(((ăYĠ)Y(ļYş))O((ăYĠ)Y(ŇYŔ))))O(((ăYģ)Y(ļYŜ))O(((ăYģ)Y(ńYŔ))O((ĈYĘ)Y(ĿYş))))))O(((((ĈYĘ)Y(ŇYŗ))
# ...

# %%
# %%time
A = inorder_to_tree(Ytoria_balanceada(n.reglas))
print(A.ver(n.NenC))
# Out:
# (((((((((((((((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 10  está en la casilla (5) Y El número 11  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 11  está en la casilla (5) Y El número 10  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 10  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 11  está en la casilla (7))))) O (((El número 0  está en la casilla (0) Y El número 10  está en la casilla (2)) Y (El número 11  está en la casilla (5) Y El número 1  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 11  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 10  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 11  está en la casilla (2)) Y (El número 10  está en la casilla (5) Y El número 1  está en la casilla (7)))))) O ((((El número 1  
# ...

# %%
import sys

# %%
sys.getrecursionlimit()
# Out:
# 3000

# %%
sys.setrecursionlimit(10000000)
sys.getrecursionlimit()
# Out:
# 10000000

# %% [markdown]
# ---

# %% [markdown]
# # Solución de problemas

# %% [markdown]
# ## Expansión primero en anchura <a class="anchor" id="anchura"></a>
#
# La implementación en Python es la siguiente:

# %%
def primero_anchura(nodo):
    estado = nodo
    res = estado.es_hoja()
    if res == 'cerrada':
        return None
    elif res == 'abierta':
        return estado.interp()
    frontera = [estado]
    while len(frontera) > 0:
        estado = frontera.pop(0) 
        hijos = estado.expandir()
        for a in hijos:
            if a != None:
                res = a.es_hoja()
                if res == 'abierta':
                    return a.interp()
                elif res == None:
                    frontera.append(a)
    return None

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = [inorder_to_tree(n.reglas[0])]
n1 = nodos_tableaux(A)
I1 = primero_anchura(n1)
print("Resultado:", I1)

# %%
# %%time
if I1 != None:
    n.visualizar(I1)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Regla 2

# %%
# %%time
A = [inorder_to_tree(n.reglas[1])]
n2 = nodos_tableaux(A)
I2 = primero_anchura(n2)
print("Resultado:", I2)
# Out:
# CPU times: total: 3min 9s
# Wall time: 3min 12s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'A = [inorder_to_tree(n.reglas[1])]\nn2 = nodos_tableaux(A)\nI2 = primero_anchura(n2)\nprint("Resultado:", I2)\n')
#
# File <timed exec>:3
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[8], line 11, in primero_anchura(nodo)
#       7         return estado.interp()
#       8     frontera = [estado]
#       9     while len(frontera) > 0:
#      10         estado = frontera.pop(0)
# ---> 11         hijos = estado.expandir()
#      12         for a in hijos:
#      13             if a != None:
#      14                 res = a.es_hoja()
#
# File c:\Users\alejo\Downloads\Notebook REGLAS\Logica.py:421, in nodos_tableaux.expandir(self)
# ...

# %%
# %%time
if I2 != None:
    n.visualizar(I2)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Regla 3

# %%
# %%time
A = [inorder_to_tree(n.reglas[2])]
n3 = nodos_tableaux(A)
I3 = primero_anchura(n3)
print("Resultado:", I3)

# %%
# %%time
if I3 != None:
    n.visualizar(I3)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Regla 4

# %%
# %%time
A = [inorder_to_tree(n.reglas[3])]
n4 = nodos_tableaux(A)
I4 = primero_anchura(n4)
print("Resultado:", I4)

# %%
# %%time
if I4 != None:
    n.visualizar(I4)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Todas las reglas

# %%
# %%time
reg = Ytoria_balanceada(n.reglas)
A = [inorder_to_tree(reg)]
n5= nodos_tableaux(A)
I5 = primero_anchura(n5)
print("Resultado:", I5)
# Out:
# CPU times: total: 93.8 ms
# Wall time: 85 ms

# %%
# %%time
if I5 != None:
    n.visualizar(I5)
else:
    print('¡No hay solución!')

# %% [markdown]
# ---

# %% [markdown]
# # Expansión primero en profundidad <a class="anchor" id="prof"></a>
# La implementación en Python es la siguiente:

# %%
def primero_profundidad(nodo):
    estado = nodo
    res = estado.es_hoja()
    if res == 'cerrada':
        return None
    elif res == 'abierta':
        return estado.interp()
    frontera = [estado]
    while len(frontera) > 0:
        estado = frontera.pop() 
        hijos = estado.expandir()
        for a in hijos:
            if a != None:
                res = a.es_hoja()
                if res == 'abierta':
                    return a.interp()
                elif res == None:
                    frontera.append(a)
    return None

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = [inorder_to_tree(n.reglas[0])]
n1 = nodos_tableaux(A)
I1 = primero_profundidad(n1)
print("Resultado:", I1)
# Out:
# Resultado: {'ć': True, 'Ğ': True, 'Ł': True, 'Ř': True, 'ē': True, 'ĩ': True, 'Ĵ': True, 'Ī': True, 'ō': True, 'ż': True, 'ś': True, 'Ŧ': True, 'ű': True, 'ł': True, 'ť': True, 'ƈ': True, 'ķ': True, 'Ŏ': True}
# CPU times: total: 2.61 s
# Wall time: 2.75 s

# %%
# %%time
if I1 != None:
    n.visualizar(I1)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 46.9 ms
# Wall time: 101 ms

# %% [markdown]
# ### Regla 2

# %%
# %%time
A = [inorder_to_tree(n.reglas[1])]
n2 = nodos_tableaux(A)
I2 = primero_profundidad(n2)
print("Resultado:", I2)
# Out:
# Resultado: {'ċ': True, 'į': True, 'œ': True, 'ŷ': True, 'ė': True, 'ģ': True, 'Ļ': True, 'Ň': True, 'ş': True, 'ū': True, 'ƃ': True, 'Ǝ': True}
# CPU times: total: 31.2 ms
# Wall time: 36.2 ms

# %%
# %%time
if I2 != None:
    n.visualizar(I2)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 24.1 ms

# %% [markdown]
# ### Regla 3

# %%
# %%time
A = [inorder_to_tree(n.reglas[2])]
n3 = nodos_tableaux(A)
I3 = primero_profundidad(n3)
print("Resultado:", I3)
# Out:
# Resultado: {'Č': False, 'Ę': False, 'Ĥ': False, 'ň': False, 'Ŭ': False, 'İ': False, 'ļ': False, 'Ŕ': False, 'Š': False, 'Ÿ': False, 'Ƅ': False, 'Ā': False, 'č': False, 'ę': False, 'ĥ': False, 'ŉ': False, 'ŭ': False, 'ı': False, 'Ľ': False, 'ŕ': False, 'š': False, 'Ź': False, 'ƅ': False, 'ā': False, 'Ď': False, 'Ě': False, 'Ħ': False, 'Ŋ': False, 'Ů': False, 'Ĳ': False, 'ľ': False, 'Ŗ': False, 'Ţ': False, 'ź': False, 'Ɔ': False, 'Ă': False, 'ď': False, 'ě': False, 'ħ': False, 'ŋ': False, 'ů': False, 'ĳ': False, 'Ŀ': False, 'ŗ': False, 'ţ': False, 'Ż': False, 'Ƈ': False, 'ă': False, 'Đ': False, 'Ĝ': False, 'Ĩ': False, 'Ō': False, 'Ű': False, 'Ĵ': False, 'ŀ': False, 'Ř': False, 'Ť': False, 'ż': False, 'ƈ': False, 'Ą': False, 'đ': False, 'ĝ': False, 'ĩ': False, 'ō': False, 'ű': False, 'ĵ': False, 'Ł': False, 'ř': False, 'ť': False, 'Ž': False, 'Ɖ': False, 'ą': False, 'Ē': False, 'Ğ': False, 'Ī': False, 'Ŏ': False, 'Ų': False, 'Ķ': False, 'ł': False, 'Ś': False, 'Ŧ': False, 'ž': False, 'Ɗ
# ...

# %%
# %%time
if I3 != None:
    n.visualizar(I3)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13.1 ms

# %% [markdown]
# ### Regla 4

# %%
# %%time
A = [inorder_to_tree(n.reglas[3])]
n4 = nodos_tableaux(A)
I4 = primero_profundidad(n4)
print("Resultado:", I4)
# Out:
# Resultado: {'ā': False, 'Ą': False, 'ć': False, 'Ċ': False, 'Ă': False, 'ą': False, 'Ĉ': False, 'ċ': False, 'ă': False, 'Ć': False, 'ĉ': False, 'Ā': False, 'č': False, 'Đ': False, 'ē': False, 'Ė': False, 'Ē': False, 'ĕ': False, 'Č': False, 'ď': False, 'Ĕ': False, 'ė': False, 'Ď': False, 'đ': False, 'Ě': False, 'ġ': False, 'Ę': False, 'Ĝ': False, 'ğ': False, 'Ģ': False, 'ę': False, 'ĝ': False, 'Ġ': False, 'ģ': False, 'Ğ': False, 'ě': False, 'ĥ': False, 'Ĩ': False, 'ī': False, 'Į': False, 'Ħ': False, 'ĩ': False, 'Ĭ': False, 'į': False, 'ħ': False, 'Ī': False, 'ĭ': False, 'Ĥ': False, 'ı': False, 'Ĵ': False, 'ķ': False, 'ĺ': False, 'Ķ': False, 'Ĺ': False, 'İ': False, 'ĳ': False, 'ĸ': False, 'Ļ': False, 'Ĳ': False, 'ĵ': False, 'ľ': False, 'Ņ': False, 'ļ': False, 'ŀ': False, 'Ń': False, 'ņ': False, 'Ľ': False, 'Ł': False, 'ń': False, 'Ň': False, 'ł': False, 'Ŀ': False, 'ŉ': False, 'Ō': False, 'ŏ': False, 'Œ': False, 'Ŋ': False, 'ō': False, 'Ő': False, 'œ': False, 'ŋ': False, 'Ŏ': False, 'ő
# ...

# %%
# %%time
if I4 != None:
    n.visualizar(I4)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13.2 ms

# %% [markdown]
# ### Todas las reglas

# %%
# %%time
reg = Ytoria_balanceada(n.reglas)
A5 = [inorder_to_tree(reg)]
n5= nodos_tableaux(A5)
I5 = primero_profundidad(n5)
print("Resultado:", I5)
# Out:
# CPU times: total: 10h 32min 32s
# Wall time: 10h 42min 2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'reg = Ytoria_balanceada(n.reglas)\nA = [inorder_to_tree(reg)]\nn5= nodos_tableaux(A)\nI5 = primero_profundidad(n5)\nprint("Resultado:", I5)\n')
#
# File <timed exec>:4
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[9], line 11, in primero_profundidad(nodo)
#       7         return estado.interp()
#       8     frontera = [estado]
#       9     while len(frontera) > 0:
#      10         estado = frontera.pop()
# ---> 11         hijos = estado.expandir()
#      12         for a in hijos:
#      13             if a != None:
#      14                 res = a.es_hoja()
#
# ...

# %%
# %%time
if I5 != None:
    n.visualizar(I5)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Todas las reglas + Condición inical

# %%
# %%time
#Resolvemos una línea para facilitarle el trabajo :)
c1 = n.NenC.ravel([0, 1])
c2 = n.NenC.ravel([11, 2])
c3 = n.NenC.ravel([5, 3])
c4 = n.NenC.ravel([9, 4])
cond_iniciales = [c1, c2, c3, c4]

#En vez de hacer Ytoria solo pasamos todo a inorder, de todas formas se tienen que cumplir todas tons es como una Ytoria sin serlo y ps es más eficiente
A6 = [inorder_to_tree(r) for r in n.reglas] + [inorder_to_tree(c) for c in cond_iniciales]
n6 = nodos_tableaux(A6)
I6 = primero_profundidad(n6)
print("Resultado:", I6)
# Out:
# CPU times: total: 15h 9min 11s
# Wall time: 15h 27min 51s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', '#Resolvemos una línea para facilitarle el trabajo :)\nc1 = n.NenC.ravel([0, 1])\nc2 = n.NenC.ravel([11, 2])\nc3 = n.NenC.ravel([5, 3])\nc4 = n.NenC.ravel([9, 4])\ncond_iniciales = [c1, c2, c3, c4]\n\n#En vez de hacer Ytoria solo pasamos todo a inorder, de todas formas se tienen que cumplir todas tons es como una Ytoria sin serlo y ps es más eficiente\nA6 = [inorder_to_tree(r) for r in n.reglas] + [inorder_to_tree(c) for c in cond_iniciales]\nn6 = nodos_tableaux(A6)\nI6 = primero_profundidad(n6)\nprint("Resultado:", I6)\n')
#
# File <timed exec>:11
#
# Cell In[8], line 11, in primero_profundidad(nodo)
#       7         return estado.interp()
#       8     frontera = [estado]
# ...

# %%
# %%time
if I6 != None:
    n.visualizar(I6)
else:
    print('¡No hay solución!')

# %% [markdown]
# ---

# %% [markdown]
# # Recorrido con backtracking <a class="anchor" id="backt"></a>
# La implementación en Python es la siguiente:

# %%
def backtracking(nodo):
    estado = nodo
    res = estado.es_hoja()
    if res == 'cerrada':
        return None
    elif res == 'abierta':
        return estado.interp()
    hijos = estado.expandir()
    for hijo in hijos:
        if hijo != None:
            res = backtracking(hijo)
            if res is not None:
                return res
    return None

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = [inorder_to_tree(n.reglas[0])]
n1 = nodos_tableaux(A)
I1 = backtracking(n1)
print("Resultado:", I1)
# Out:
# Resultado: {'Ā': True, 'ę': True, 'ņ': True, 'ş': True, 'Č': True, 'Į': True, 'Ļ': True, 'ĥ': True, 'Œ': True, 'ƃ': True, 'Ŕ': True, 'š': True, 'Ŷ': True, 'Ľ': True, 'Ū': True, 'Ə': True, 'İ': True, 'ŉ': True}
# CPU times: total: 2.41 s
# Wall time: 2.43 s

# %%
# %%time
if I1 != None:
    n.visualizar(I1)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 31.2 ms
# Wall time: 24.8 ms

# %% [markdown]
# ### Regla 2

# %%
# %%time
A = [inorder_to_tree(n.reglas[1])]
n2 = nodos_tableaux(A)
I2 = backtracking(n2)
print("Resultado:", I2)
# Out:
# Resultado: {'Ā': True, 'Ĥ': True, 'ň': True, 'Ŭ': True, 'Č': True, 'Ę': True, 'İ': True, 'ļ': True, 'Ŕ': True, 'Š': True, 'Ÿ': True, 'Ƅ': True}
# CPU times: total: 31.2 ms
# Wall time: 34.9 ms

# %%
# %%time
if I2 != None:
    n.visualizar(I2)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 24.3 ms

# %% [markdown]
# ### Regla 3

# %%
# %%time
A = [inorder_to_tree(n.reglas[2])]
n3 = nodos_tableaux(A)
I3 = backtracking(n3)
print("Resultado:", I3)
# Out:
# Resultado: {'Ā': False, 'Č': False, 'Ę': False, 'Ĥ': False, 'İ': False, 'ļ': False, 'ň': False, 'Ŭ': False, 'Ÿ': False, 'Ƅ': False, 'ā': False, 'č': False, 'ę': False, 'ĥ': False, 'ŉ': False, 'ŕ': False, 'š': False, 'ŭ': False, 'Ź': False, 'ƅ': False, 'Ă': False, 'Ħ': False, 'Ĳ': False, 'ľ': False, 'Ŋ': False, 'Ŗ': False, 'Ţ': False, 'Ů': False, 'ă': False, 'ď': False, 'ě': False, 'ħ': False, 'ĳ': False, 'Ŀ': False, 'ŋ': False, 'ů': False, 'Ż': False, 'Ƈ': False, 'Ą': False, 'Đ': False, 'Ĝ': False, 'Ĩ': False, 'Ō': False, 'Ř': False, 'Ť': False, 'Ű': False, 'ż': False, 'ƈ': False, 'ą': False, 'ĩ': False, 'ĵ': False, 'Ł': False, 'ō': False, 'ř': False, 'ť': False, 'ű': False, 'Ć': False, 'Ē': False, 'Ğ': False, 'Ī': False, 'Ķ': False, 'ł': False, 'Ŏ': False, 'Ų': False, 'ž': False, 'Ɗ': False, 'ć': False, 'ē': False, 'ğ': False, 'ī': False, 'ŏ': False, 'ś': False, 'ŧ': False, 'ų': False, 'ſ': False, 'Ƌ': False, 'Ĉ': False, 'Ĭ': False, 'ĸ': False, 'ń': False, 'Ő': False, 'Ŝ': False, 'Ũ
# ...

# %%
# %%time
if I3 != None:
    n.visualizar(I3)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 13.6 ms

# %% [markdown]
# ### Regla 4

# %%
# %%time
A = [inorder_to_tree(n.reglas[3])]
n4 = nodos_tableaux(A)
I4 = backtracking(n4)
print("Resultado:", I4)
# Out:
# Resultado: {'Ā': False, 'ā': False, 'Ă': False, 'ă': False, 'Ą': False, 'ą': False, 'Ć': False, 'ć': False, 'Ĉ': False, 'ĉ': False, 'Ċ': False, 'ċ': False, 'Č': False, 'č': False, 'Ď': False, 'ď': False, 'Đ': False, 'đ': False, 'Ē': False, 'ē': False, 'Ĕ': False, 'ĕ': False, 'Ė': False, 'ė': False, 'Ę': False, 'ę': False, 'Ě': False, 'ě': False, 'Ĝ': False, 'ĝ': False, 'Ğ': False, 'ğ': False, 'Ġ': False, 'ġ': False, 'Ģ': False, 'ģ': False, 'Ĥ': False, 'ĥ': False, 'Ħ': False, 'ħ': False, 'Ĩ': False, 'ĩ': False, 'Ī': False, 'ī': False, 'Ĭ': False, 'ĭ': False, 'Į': False, 'į': False, 'İ': False, 'ı': False, 'Ĳ': False, 'ĳ': False, 'Ĵ': False, 'ĵ': False, 'Ķ': False, 'ķ': False, 'ĸ': False, 'Ĺ': False, 'ĺ': False, 'Ļ': False, 'ļ': False, 'Ľ': False, 'ľ': False, 'Ŀ': False, 'ŀ': False, 'Ł': False, 'ł': False, 'Ń': False, 'ń': False, 'Ņ': False, 'ņ': False, 'Ň': False, 'ň': False, 'ŉ': False, 'Ŋ': False, 'ŋ': False, 'Ō': False, 'ō': False, 'Ŏ': False, 'ŏ': False, 'Ő': False, 'ő': False, 'Œ
# ...

# %%
# %%time
if I4 != None:
    n.visualizar(I4)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 15.6 ms
# Wall time: 11.8 ms

# %% [markdown]
# ### Todas las reglas

# %%
# %%time
reg = Ytoria_balanceada(n.reglas)
A = [inorder_to_tree(reg)]
n5= nodos_tableaux(A)
I5 = backtracking(n5)
print("Resultado:", I5)
# Out:
# CPU times: total: 6h 16min 38s
# Wall time: 6h 22min 7s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'reg = Ytoria_balanceada(n.reglas)\nA = [inorder_to_tree(reg)]\nn5= nodos_tableaux(A)\nI5 = backtracking(n5)\nprint("Resultado:", I5)\n')
#
# File <timed exec>:4
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[18], line 11, in backtracking(nodo)
#       7         return estado.interp()
#       8     hijos = estado.expandir()
#       9     for hijo in hijos:
#      10         if hijo != None:
# ---> 11             res = backtracking(hijo)
#      12             if res is not None:
#      13                 return res
#      14     return None
#
# Cell In[18], line 11, in backtracking(nodo)
#       7         return estado.interp()
# ...

# %%
# %%time
if I5 != None:
    n.visualizar(I5)
else:
    print('¡No hay solución!')

# %% [markdown]
# ### Todas las reglas + Condición inical

# %%
# %%time
#Resolvemos una línea para facilitarle el trabajo :)
c1 = n.NenC.ravel([0, 1])
c2 = n.NenC.ravel([11, 2])
c3 = n.NenC.ravel([5, 3])
c4 = n.NenC.ravel([9, 4])
cond_iniciales = [c1, c2, c3, c4]

#En vez de hacer Ytoria solo pasamos todo a inorder, de todas formas se tienen que cumplir todas tons es como una Ytoria sin serlo y ps es más eficiente
A6 = [inorder_to_tree(r) for r in n.reglas] + [inorder_to_tree(c) for c in cond_iniciales]
n6 = nodos_tableaux(A6)
I6 = backtracking(n6)
print("Resultado:", I6)
# Out:
# CPU times: total: 10h 32min 32s
# Wall time: 10h 42min 2s
# ---------------------------------------------------------------------------
#
# KeyboardInterrupt                         Traceback (most recent call last)
#
# Cell In[19], line 1
#
# ----> 1 get_ipython().run_cell_magic('time', '', 'reg = Ytoria_balanceada(n.reglas)\nA = [inorder_to_tree(reg)]\nn5= nodos_tableaux(A)\nI5 = primero_profundidad(n5)\nprint("Resultado:", I5)\n')
#
#
#
# File <timed exec>:4
#
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
#
#
# Cell In[9], line 11, in primero_profundidad(nodo)
#
#       7         return estado.interp()
#
#       8     frontera = [estado]
#
#       9     while len(frontera) > 0:
#
#      10         estado = frontera.pop()
#
# ---> 11         hijos = estado.expandir()
#
#      12         for a in hijos:
#
#      13             if a != None:
#
#      14                 res = a.es_hoja()
#
#
#
# ...

# %%
# %%time
if I6 != None:
    n.visualizar(I6)
else:
    print('¡No hay solución!')

# %% [markdown]
# ---
