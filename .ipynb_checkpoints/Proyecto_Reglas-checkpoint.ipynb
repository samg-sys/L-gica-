# %% [markdown]
# <table>
#     <tr>
#         <td><img src="./img/Macc.png" width="auto"/></td>
#         <td>
#             <table><tr>
#             <h1 style="color:blue;text-align:center">Lógica para Ciencias de la Computación</h1></td>
#             </tr></table>
#         <td>&nbsp;</td>
#         <td>
#             <table><tr>
#             <tp><p style="font-size:150%;text-align:center">Proyecto </p></tp>
#             <tp><p style="font-size:150%;text-align:center">Representación de reglas</p></tp>
#             </tr></table>
#         </td>
#     </tr>
# </table>
#
# ---

# %% [markdown]
# # Secciones
#
# 1. [Solución de restricciones.](#rest)
#     1. [Problema ilustrativo.](#prob)
#     2. [Implementación de las restricciones.](#forms)
#     3. [Visualización.](#vis)
#     4. [Solución mediante SATtabla.](#sat)
#     5. [Un problema más difícil.](#prob2)
#     6. [Situaciones más complejas y comparación de tiempos.](#comp)
# 2. [Solución de preguntas.](#preg)

# %% [markdown]
# ## Descripción del problema <a class="anchor" id="prob"></a>
#
# ([Volver al inicio](#inicio))
#
#
# Este es uno de los hexagramas mágicos que cumplen con las condiciones:
#
# <img src="./img/problema.png" width="400px"/>

# %% [markdown]
# ## Reglas <a class="anchor" id="forms"></a>
#
# Para hacer más concisa la primera regla, hacemos la siguiente definición de lo que son las lineas rectas en el hexagrama (tenga en cuenta que las lineas son un subconjunto de todas las casillas):
#
# $$l_1 = \{1,3,6,8\}$$
# $$l_2 = \{1,4,7,11\}$$
# $$l_3 = \{8,9,10,11\}$$
# $$l_4 = \{2,3,4,5\}$$
# $$l_5 = \{2,6,9,12\}$$
# $$l_6 = \{5,7,10,12\}$$
#
# Las restricciones y su representación usando lógica proposicional son las siguientes:
#
# 1. La suma de los números en cualquier línea recta es 26:
#
# $$\bigwedge_{l \in Lineas} \left(\bigvee_{n \in Numeros} NenC_{n,l_{[1]}}+NenC_{n,l_{[2]}}+NenC_{n,l_{[3]}}+NenC_{n,l_{[4]}} = NenC_{26,l_{[1]}+l_{[2]}+l_{[3]}+l_{[4]}}\right)$$
#
# 2. Todas las casillas deben estar ocupadas:
# $$\bigwedge_{c \in Casillas} \left(\bigvee_{n \in Numeros}NenC_{n,c}\right)$$
#
#
# 3. No pueden haber números repetidos:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{e \neq c} NenC_{n,e}\right)\right)$$
#
#
# 4. Solo debe haber un número por casilla:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{m \neq n} NenC_{m,c}\right)\right)$$

# %% [markdown]
# ## Implementación de las restricciones <a class="anchor" id="forms"></a>
#
# ([Volver al inicio](#inicio))
#
# En la librería `Hexagramas` hemos implementado las tres reglas. Puede correr el siguiente código para visualizar el resultado, y puede entrar a la librería para explorar la implementación:

# %%
from Hexagrama_arr import *
from Logica import *

# %%
n = Numero()

# %% [markdown]
# Observe que el objeto tiene un atributo `reglas`, en el cual está una lista con las tres reglas implementadas en Python:

�>-ĥ))Y((Ĕ>-Ħ)Y((Ĕ>-ħ)Y(ĕ>-Ĕ)))))Y((((ĕ>-Ė)Y(ĕ>-ė))Y((ĕ>-Ę)Y(ĕ>-ę)))Y(((ĕ>-Ě)Y(ĕ>-ě))Y((ĕ>-Ĝ)Y((ĕ>-ĝ)Y(ĕ>-Ğ))))))Y(((((ĕ>-ğ)Y(ĕ>-Ġ))Y((ĕ>-ġ)Y(ĕ>-Ģ)))Y(((ĕ>-ģ)Y(ĕ>-Ĥ))Y((ĕ>-ĥ)Y((ĕ>-Ħ)Y(ĕ>-ħ)))))Y((((Ė>-Ĕ)Y(Ė>-ĕ))Y((Ė>-ė)Y(Ė>-Ę)))Y(((Ė>-ę)Y(Ė>-Ě))Y((Ė>-ě)Y((Ė>-Ĝ)Y(Ė>-ĝ)))))))))Y((((((((Ė>-Ğ)Y(Ė>-ğ))Y((Ė>-Ġ)Y(Ė>-ġ)))Y(((Ė>-Ģ)Y(Ė>-ģ))Y((Ė>-Ĥ)Y(Ė>-ĥ))))Y((((Ė>-Ħ)Y(Ė>-ħ))Y((ė>-Ĕ)Y(ė>-ĕ)))Y(((ė>-Ė)Y(ė>-Ę))Y((ė>-ę)Y((ė>-Ě)Y(ė>-ě))))))Y ...

# %% [markdown]
# La clase `Numero` crea de una vez el descriptor, mediante el cual podemos decodificar las letras:

# %%
n.NenC.escribir('ñ')
# Out:
# 'El número 5  está en la casilla (0)'

# %%
n.NenC.escribir('Ç')
# Out:
# 'El número 3  está en la casilla (-2)'

# %% [markdown]
# También podemos revisar regla por regla. Observe que las fórmulas incluyen un método `ver` para visualizar más fácilmente las reglas:

# %%
# %%time
A = inorder_to_tree(n.reglas[0])
print(A.ver(n.NenC))
# Out:
# ((((((((((((((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 2  está en la casilla (5) Y El número 19  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 19  está en la casilla (5) Y El número 2  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 2  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 19  está en la casilla (7))))) O (((El número 0  está en la casilla (0) Y El número 2  está en la casilla (2)) Y (El número 19  está en la casilla (5) Y El número 1  está en la casilla (7))) O (((El número 0  está en la casilla (0) Y El número 19  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 2  está en la casilla (7))) O ((El número 0  está en la casilla (0) Y El número 19  está en la casilla (2)) Y (El número 2  está en la casilla (5) Y El número 1  está en la casilla (7)))))) O ((((El número 1  está en la casilla (0) Y El número 0  está en la casilla (2)) Y (El número 2  está en la casilla (5) Y El número 19  está en la casilla (7))) O (((El número 1  está en la casilla (0) Y El número 0  está en la casilla (2)) Y (El número 19  está en la casilla (5) Y El número 2  está en la casilla (7))) O ((El número 1  está en la casilla (0) Y El número 2  está en la casilla (2)) Y (El número 0  está en la casilla (5) Y El número 19  está en la casilla (7)))))
está en la casilla (7))))) O (((El número 2  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 19  está en la casilla (5) Y El número 0  está en la casilla (7))) O (((El número 2  está en la casilla (0) Y El número 19  está en la casilla (2)) Y (El número 0  está en la casilla (5) Y El número 1  está en la casilla (7))) O ((El número 2  está en la casilla (0) Y El número 19  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 0  está en la casilla (7)))))) O ((((El número 19  está en la casilla (0) Y El número 0  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 2  está en la casilla (7))) O (((El número 19  está en la casilla (0) Y El número 0  está en la casilla (2)) Y (El número 2  está en la casilla (5) Y El número 1  está en la casilla (7))) O ((El número 19  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 0  está en la casilla (5) Y El número 2  está en la casilla (7))))) O (((El número 19  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 2  está en la casilla (5) Y El número 0  está en la casilla (7))) O (((El número 19  está en la casilla (0) Y El número 2  está en la casilla (2)) Y (El número 0  está en la casilla (5) Y El número 1  está en la casilla (7))) O ((El número 19  está en la casilla (0) Y El número 2  está en la casilla (2)) Y (El número 1  está en la casilla (5) Y El número 0  está en la casilla (7)))))))) O ((((((El número 0  está en la casilla (0) Y El número 1  está en la casilla (2)) Y (El número 3  está en la casilla (5) Y El núm ...
# CPU times: total: 1.52 s
# Wall time: 1.49 s

# %% [markdown]
# ## Visualización <a class="anchor" id="vis"></a>
#
# ([Volver al inicio](#inicio))
#
# El método `visualizar` permite representar visualmente el hexagrama mágico. \
# Ejemplo:

# %%
I = {}
for c in range(12):
    m = c  #Mismo numero en misma casilla
    literal = n.NenC.ravel([m, c])
    I[literal] = True

n.visualizar(I)

# %% [markdown]
# Ahora visualizaremos cada regla con SATtableaux pq SATtabla es tenaz

# %%
import sys
sys.getrecursionlimit()
# Out:
# 3000

# %%
sys.setrecursionlimit(50000)
sys.getrecursionlimit()
# Out:
# 50000

# %% [markdown]
# ### Regla 1

# %%
# %%time
A = inorder_to_tree(n.reglas[0])
I = A.SATtableaux()
if I != None:
    n.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 12min
# Wall time: 12min 2s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "A = inorder_to_tree(n.reglas[0])\nI = A.SATtableaux()\nif I != None:\n    n.visualizar(I)\nelse:\n    print('¡No hay solución!')\n")
#
# File <timed exec>:2
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:101, in Formula.SATtableaux(self)
#      99 while len(frontera) > 0:
#     100     estado = frontera.pop(0)
# --> 101     hijos = estado.expandir()
#     102     for a in hijos:
#     103         if a != None:
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:367, in nodos_tableaux.expandir(self)
#     365     B2 = f.right
#     366 f_alfas2 = deepcopy(f_alfas)
# --> 367 f_betas2 = deepcopy(f_betas)
#     368 f_literales2 = deepcopy(f_literales)
#     369 clasf = B1.clasifica_para_tableaux()
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:202, in _deepcopy_tuple(x, memo, deepcopy)
#     201 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 202     y = [deepcopy(a, memo) for a in x]
#     203     # We're not going to put the tuple in the memo, but it's still important we
#     204     # check for it, in case the tuple contains recursive mutable structures.
#     205     try:
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 222 (9 times), _reconstruct at line 260 (9 times), deepcopy at line 163 (9 times), deepcopy at line 137 (9 times)]
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:135, in deepcopy(x, memo, _nil)
#     131         return y
#     133 cls = type(x)
# --> 135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
#     137     y = copier(x, memo)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Regla 2

# %%
# %%time
A = inorder_to_tree(n.reglas[1])
I = A.SATtableaux()
if I != None:
    n.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 1.59 s
# Wall time: 1.59 s

# %% [markdown]
# ### Regla 3

# %%
# %%time
A = inorder_to_tree(n.reglas[2])
I = A.SATtableaux()
if I != None:
    n.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 4min 30s
# Wall time: 4min 30s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "A = inorder_to_tree(n.reglas[2])\nI = A.SATtableaux()\nif I != None:\n    n.visualizar(I)\nelse:\n    print('¡No hay solución!')\n")
#
# File <timed exec>:2
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:101, in Formula.SATtableaux(self)
#      99 while len(frontera) > 0:
#     100     estado = frontera.pop(0)
# --> 101     hijos = estado.expandir()
#     102     for a in hijos:
#     103         if a != None:
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:327, in nodos_tableaux.expandir(self)
#     325 '''Escoge última alfa, si no última beta, si no None'''
#     326 f_alfas = deepcopy(self.alfas)
# --> 327 f_betas = deepcopy(self.betas)
#     328 f_literales = deepcopy(self.literales)
#     329 if len(self.alfas) > 0:
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:202, in _deepcopy_tuple(x, memo, deepcopy)
#     201 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 202     y = [deepcopy(a, memo) for a in x]
#     203     # We're not going to put the tuple in the memo, but it's still important we
#     204     # check for it, in case the tuple contains recursive mutable structures.
#     205     try:
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
#     [... skipping similar frames: _deepcopy_dict at line 222 (2 times), _reconstruct at line 260 (2 times), deepcopy at line 163 (2 times), deepcopy at line 137 (2 times)]
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
#     [... skipping similar frames: deepcopy at line 137 (1 times)]
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:173, in _deepcopy_atomic(x, memo)
#     169     return y
#     171 _deepcopy_dispatch = d = {}
# --> 173 def _deepcopy_atomic(x, memo):
#     174     return x
#     175 d[types.NoneType] = _deepcopy_atomic
#
# KeyboardInterrupt:

# %% [markdown]
# ### Regla 4

# %%
# %%time
A = inorder_to_tree(n.reglas[3])
I = A.SATtableaux()
if I != None:
    n.visualizar(I)
else:
    print('¡No hay solución!')
# Out:
# CPU times: total: 4min 35s
# Wall time: 4min 35s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', "A = inorder_to_tree(n.reglas[3])\nI = A.SATtableaux()\nif I != None:\n    n.visualizar(I)\nelse:\n    print('¡No hay solución!')\n")
#
# File <timed exec>:2
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:101, in Formula.SATtableaux(self)
#      99 while len(frontera) > 0:
#     100     estado = frontera.pop(0)
# --> 101     hijos = estado.expandir()
#     102     for a in hijos:
#     103         if a != None:
#
# File ~\Downloads\Universidad del Rosario\Matemáticas Aplicadas y Ciencias de la Computación (MACC)\2 Semestre\Lógica para ciencias de la computación\Proyecto\Proyecto real\Notebook REGLAS\Logica.py:326, in nodos_tableaux.expandir(self)
#     324 def expandir(self):
#     325     '''Escoge última alfa, si no última beta, si no None'''
# --> 326     f_alfas = deepcopy(self.alfas)
#     327     f_betas = deepcopy(self.betas)
#     328     f_literales = deepcopy(self.literales)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:197, in _deepcopy_list(x, memo, deepcopy)
#     195 append = y.append
#     196 for a in x:
# --> 197     append(deepcopy(a, memo))
#     198 return y
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:202, in _deepcopy_tuple(x, memo, deepcopy)
#     201 def _deepcopy_tuple(x, memo, deepcopy=deepcopy):
# --> 202     y = [deepcopy(a, memo) for a in x]
#     203     # We're not going to put the tuple in the memo, but it's still important we
#     204     # check for it, in case the tuple contains recursive mutable structures.
#     205     try:
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:163, in deepcopy(x, memo, _nil)
#     161                 y = x
#     162             else:
# --> 163                 y = _reconstruct(x, memo, *rv)
#     165 # If is its own copy, don't memoize.
#     166 if y is not x:
#
# File ~\anaconda3\Lib\copy.py:260, in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     258 if state is not None:
#     259     if deep:
# --> 260         state = deepcopy(state, memo)
#     261     if hasattr(y, '__setstate__'):
#     262         y.__setstate__(state)
#
# File ~\anaconda3\Lib\copy.py:137, in deepcopy(x, memo, _nil)
#     135 copier = _deepcopy_dispatch.get(cls)
#     136 if copier is not None:
# --> 137     y = copier(x, memo)
#     138 else:
#     139     if issubclass(cls, type):
#
# File ~\anaconda3\Lib\copy.py:222, in _deepcopy_dict(x, memo, deepcopy)
#     220 memo[id(x)] = y
#     221 for key, value in x.items():
# --> 222     y[deepcopy(key, memo)] = deepcopy(value, memo)
#     223 return y
#
# File ~\anaconda3\Lib\copy.py:168, in deepcopy(x, memo, _nil)
#     166 if y is not x:
#     167     memo[d] = y
# --> 168     _keep_alive(x, memo) # Make sure x lives at least as long as d
#     169 return y
#
# File ~\anaconda3\Lib\copy.py:243, in _keep_alive(x, memo)
#     233 """Keeps a reference to the object x in the memo.
#     234
#     235 Because we remember objects by their id, we have
#    (...)    240 the memo itself...
#     241 """
#     242 try:
# --> 243     memo[id(memo)].append(x)
#     244 except KeyError:
#     245     # aha, this is the first one :-)
#     246     memo[id(memo)]=[x]
#
# KeyboardInterrupt:

# %% [markdown]
# ---

# %% [markdown]
# ## Visualización de una solución

# %%
I = {}
literal1 = n.NenC.ravel([5,0])
I[literal1] = True
literal2 = n.NenC.ravel([4,1])
I[literal2] = True
literal3 = n.NenC.ravel([6,2])
I[literal3] = True
literal4 = n.NenC.ravel([10,3])
I[literal4] = True
literal5 = n.NenC.ravel([2,4])
I[literal5] = True
literal6 = n.NenC.ravel([8,5])
I[literal6] = True
literal7 = n.NenC.ravel([0,6])
I[literal7] = True
literal8 = n.NenC.ravel([3,7])
I[literal8] = True
literal9 = n.NenC.ravel([1,8])
I[literal9] = True
literal10 = n.NenC.ravel([11,9])
I[literal10] = True
literal11 = n.NenC.ravel([7,10])
I[literal11] = True
literal12 = n.NenC.ravel([9,11])
I[literal12] = True

n.visualizar(I)
