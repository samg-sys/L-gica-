# %% [markdown]
# # Importar problema

# %%
from Logica import *
from Hexagrama_arr import *

# %% [markdown]
# ## Reglas <a class="anchor" id="forms"></a>
#
# Para hacer más concisa la primera regla, hacemos la siguiente definición de lo que son las lineas rectas en el hexagrama (tenga en cuenta que las lineas son un subconjunto de todas las casillas):
#
# $$l_1 = \{1,3,6,8\}$$
# $$l_2 = \{1,4,7,11\}$$
# $$l_3 = \{8,9,10,11\}$$
# $$l_4 = \{2,3,4,5\}$$
# $$l_5 = \{2,6,9,12\}$$
# $$l_6 = \{5,7,10,12\}$$
#
# Las restricciones y su representación usando lógica proposicional son las siguientes:
#
# 1. La suma de los números en cualquier línea recta es 26:
#
# $$\bigwedge_{l \in Lineas} \left(\bigvee_{n \in Numeros} NenC_{n,l_{[1]}}+NenC_{n,l_{[2]}}+NenC_{n,l_{[3]}}+NenC_{n,l_{[4]}} = NenC_{26,l_{[1]}+l_{[2]}+l_{[3]}+l_{[4]}}\right)$$
#
# 2. Todas las casillas deben estar ocupadas:
# $$\bigwedge_{c \in Casillas} \left(\bigvee_{n \in Numeros}NenC_{n,c}\right)$$
#
#
# 3. No pueden haber números repetidos:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{e \neq c} NenC_{n,e}\right)\right)$$
#
#
# 4. Solo debe haber un número por casilla:
# $$\bigwedge_{n \in Numeros} \bigwedge_{c \in Casillas}\left(NenC_{n,c} \rightarrow \neg \left(\bigvee_{m \neq n} NenC_{m,c}\right)\right)$$

# %%
n = Numero()

# %% [markdown]
# ---

# %% [markdown]
# # Solución de problemas

# %% [markdown]
# Buscamos una solución mediante el WalkSAT:

# %%
import sys

# %%
sys.getrecursionlimit()
# Out:
# 3000

# %%
sys.setrecursionlimit(10000000)
sys.getrecursionlimit()
# Out:
# 10000000

# %% [markdown]
# ### Regla 1

# %%
# %%time
A1 = n.reglas[0]
B1 = tseitin(A1)
I1 = {}
I1 = walkSAT(A1,B1)
print("Modelo:")
print(I1)

# %%
# %%time
if I1 is not None:
    print("Satisfacible")
    n.visualizar(I1)
else:
    print("¡No hay solución!")

# %% [markdown]
# ### Regla 2

# %%
# %%time
A2 = n.reglas[1]
B2 = tseitin(A2)
I2 = {}
I2 = walkSAT(A2,B2)
print("Modelo:")
print(I2)
# Out:
# Modelo:
# {'Ń': False, 'Ŏ': False, 'ŝ': False, 'Ŧ': True, 'Ǝ': False, 'Ł': False, 'Ś': False, 'ŷ': False, 'Ɔ': False, 'Ď': False, 'Đ': False, 'Ż': False, 'ŕ': False, 'ŋ': True, 'Ƅ': False, 'ă': False, 'ƈ': False, 'ĥ': True, 'ŧ': True, 'ſ': True, 'Ɗ': False, 'Ļ': False, 'š': False, 'ķ': True, 'į': True, 'ĵ': False, 'Ŝ': False, 'Ī': False, 'ŉ': False, 'ē': True, 'Ů': False, 'Ű': False, 'Ɓ': False, 'ľ': True, 'Ő': False, 'Ŀ': False, 'Ĵ': False, 'Ă': False, 'Ŕ': False, 'Ē': False, 'Ĺ': True, 'Ň': False, 'ű': False, 'ź': False, 'ĳ': False, 'ċ': False, 'ą': False, 'Ƈ': True, 'ƃ': False, 'Į': False, 'ā': False, 'ı': False, 'Ğ': True, 'č': False, 'Ş': False, 'ĉ': True, 'ž': False, 'Ř': False, 'ĩ': False, 'Ĭ': False, 'İ': False, 'ļ': True, 'Ŷ': False, 'ƍ': False, 'Ž': False, 'Ĕ': True, 'ł': False, 'ī': True, 'ŀ': False, 'Ō': False, 'Ŗ': False, 'ė': False, 'ğ': False, 'Ě': False, 'ŏ': False, 'ģ': False, 'œ': False, 'ě': False, 'ĺ': False, 'ĕ': True, 'Ū': False, 'ŭ': False, 'Ũ': True, 'Ħ': False, 'ň': False, 'ć': False, 'ũ': False, 'Ƃ': True, 'Ĩ': False, 'Ė': True, 'ō': False, 'ƌ': False, 'Ę': False, 'ƅ': False, 'Ĝ': False, 'Ā': False, 'Ċ': False, 'ħ': False, 'Ə': False, 'ņ': False, 'ĝ': False, 'Ų': True, 'ŵ': False, 'ĸ': False, 'Ŋ': False, 'ŗ': True, 'Ƌ': False, 'Ť': True, 'Ţ': False, 'Ŵ': False, 'Ķ': False, 'ų': False, 'ţ': False, 'Ņ': False, 'Ġ': False, 'Ģ': False, 'ś': False, 'ū': False, 'Ĳ': False, 'Ľ': False, 'ĭ': True, 'Ć': False, 'Ą': False, 'ń': False, 'ď': False, 'ů': False, 'đ': True, 'ř': False, 'ƀ': True, 'Ĉ': True, 'Ɖ': False, 'Š': False, 'ş': False, 'Œ': False, 'ť': False, 'Ÿ': False, 'ż': False, 'Ź': False, 'Ĥ': False, 'ő': False, 'Ŭ': False, 'Č': False, 'ę': True, 'ġ': False}
# CPU times: total: 844 ms
# Wall time: 838 ms

# %%
# %%time
if I2 is not None:
    print("Satisfacible")
    n.visualizar(I2)
else:
    print("¡No hay solución!")
# Out:
# Satisfacible
# CPU times: total: 93.8 ms
# Wall time: 95.1 ms

# %% [markdown]
# ### Regla 3

# %%
# %%time
A3 = n.reglas[2]
B3 = tseitin(A3)
I3 = {}
I3 = walkSAT(A3,B3)
print("Modelo:")
print(I3)
# Out:
# CPU times: total: 12h 12min 40s
# Wall time: 12h 25min 14s

# %%
# %%time
if I3 is not None:
    print("Satisfacible")
    n.visualizar(I3)
else:
    print("¡No hay solución!")
# Out:
# ¡No hay solución!
# CPU times: total: 0 ns
# Wall time: 289 μs

# %% [markdown]
# ### Regla 4

# %%
# %%time
A4 = n.reglas[3]
B4 = tseitin(A4)
I4 = {}
I4 = walkSAT(A4,B4)
print("Modelo:")
print(I4)
# Out:
# CPU times: total: 14h 28min 4s
# Wall time: 14h 42min 36s
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 get_ipython().run_cell_magic('time', '', 'A4 = n.reglas[3]\nB4 = tseitin(A4)\nI4 = {}\nI4 = w.walkSAT(B4)\nres4, I_res4 = filtro(I4, A4)\nprint(I_res4)\n')
#
# File <timed exec>:4
#       1 'Could not get source, probably due dynamically evaluated source code.'
#
# Cell In[9], line 47, in WalkSatEstado.walkSAT(A, max_flips, max_tries, p)
#      43                         v = choice(C)
#      44                     else:
#      45                         v = min_breaks[0]
#      46                 I = flip_literal(w.I, v)
# ---> 47                 w.actualizar(I)
#      48         return None
#
# Cell In[9], line 14, in WalkSatEstado.actualizar(self, I)
#      11     def actualizar(self, I):
#      12         self.I = I
#      13         self.I_lits = set([p for p in self.letrasp if self.I[p]] + ['-'+p for p in self.letrasp if not self.I[p]])
# ---> 14         self.clausulas_sat = [C for C in self.S if any((True for x in self.I_lits if x in C))]
#      15         self.clausulas_unsat = [C for C in self.S if C not in self.clausulas_sat]
#
# Cell In[9], line 14, in WalkSatEstado.actualizar.<locals>.<genexpr>(.0)
# ---> 14         self.clausulas_sat = [C for C in self.S if any((True for x in self.I_lits if x in C))]
#
# KeyboardInterrupt:

# %%
# %%time
if I4 is not None:
    print("Satisfacible")
    n.visualizar(I4)
else:
    print("¡No hay solución!")

# %% [markdown]
# ### Todas las reglas

# %%
# %%time
A5 = Ytoria_balanceada(n.reglas)
B5 = tseitin(A5)
I5 = {}
I5 = walkSAT(A5,B5)
print("Modelo:")
print(I5)

# %%
# %%time
if I5 is not None:
    print("Satisfacible")
    n.visualizar(I5)
else:
    print("¡No hay solución!")

# %% [markdown]
# ---
